# %% [markdown]
# ### 07-1 표준 모듈
# ---
# ***모듈(module)*** 이란 여러 변수와 함수를 가지고 있는 집합체

# %% [markdown]
# > 모듈, 패키지, 라이브러리

# %%
# [모듈]
# 특정 기능을 .py 파일 단위로 작성한 것

# [패키지]
# 특정 기능과 관련된 여러 모듈을 묶은 것(namespcae 제공)

# [파이썬 표준 라이브러리]
#

# %% [markdown]
# > import 모듈 가져오기

# %%
# import 모듈
# import 모듈1, 모듈2, ...

# 모듈.변수
# 모듈.함수()
# 모듈.클래스()

# %%
import math as m
m.sqrt(4.0)

# %% [markdown]
# > from import 모듈의 일부만 가져오기

# %%
#from 모듈 import 변수/함수
from math import pi
from math import sqrt as sq

pi
sq(3.0)
# Out:
# 1.7320508075688772

# %%
from math import pi as PI, sqrt as s
PI
s(PI)
# Out:
# 1.7724538509055159

# %% [markdown]
# > import 패키지 가져오기

# %%
# 패키지 : 특징 기능관 관련된 여러 모듈 묶은 것, 패키지 안에 들어 있는 모듈 가져다 쓰기
# import 패키지.모듈

import urllib.request

res = urllib.request.urlopen("https://google.com")
res.status # HTTP 상태코드 : 200(성공), 400(요청오류)
# Out:
# 200

# %%
# from 패키지.모듈 import 클래스, 함수
from urllib.request import Request, urlopen

req = Request("https://www.google.com")
res = urlopen(req)
res.status
# Out:
# 200

# %% [markdown]
# > 👍random, sys, os, datetime, time, urlib 모듈
# ---
# 자주 사용하는 모듈이므로 검색 후에 정리하는 걸 추천함
