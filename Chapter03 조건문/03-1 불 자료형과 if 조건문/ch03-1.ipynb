# %% [markdown]
# ### 03-1 불 자료형과 if 조건문
# ---
# #### 시작하기 전에
# ***Boolean***은 **불린** 또는 **불리언** : **True**(참)과 **False**(거짓)을 나타내는 값

# %%
a = True
b = False
print(a, b, type(a))
# Out:
# True False <class 'bool'>

# %% [markdown]
# >bool 만들기 : 비교연산자

# %%
# 숫자비교
print(10 == 100)
print(10 != 100)
print(10 < 100)
# Out:
# False
# True
# True

# %%
# 문자열 비교
print("KOR" == "kor")
print("KOR" == "KOR")
print("가방" != "KOR")

print("A" < "k")
print("A" < "a")

print("가방" > "하마")

print(ord("ㄱ"))
# Out:
# False
# True
# True
# True
# True
# False
# 12593

# %%
# 범위 비교
x = 25
10 < x < 30 # python 인 이게 가능함.
# 10 < x && x < 30 할 필요 없음
# Out:
# True

# %% [markdown]
# > bool 연산하기 : 논리 연산자

# %%
# bool 끼리 연산 : 논리 연산자(not, and, or) // 자바에는 && || 등..

# and 는 *ALL*의 개념 -> 모든 값이 True 이어야 True 반환
True and True
True and True and True and False

# or 는 *ANY*의 개념 -> 어느 하나라도 True이면 True로 반환
True or False
False or False or True

# not 은 *논리값 뒤집기(반대)* 개념
not True #False
not False #True

# 논리연산자 우선순위 : not > and > or
not True and False or not False  #True
# Out:
# True

# %% [markdown]
# > 논리연산자와 비교 연산자를 함께 사용

# %%
# 비교 연산자로 비교한 결과를 논리 연산자로 최종 리턴
10 == 10 and 10 != 5
10 > 5 or 10 < 3
not 10 > 5
# Out:
# False

# %% [markdown]
# > 자료형의 참과 거짓 : bool() 내장(built-in) 함수

# %%
# print(1 + True)
# 0, 0.0 이외의 모둔 숫자는 Tue
# 0과 0.0은 False로 / True는 1로 기본 Default으로 함.
bool(1233)
bool(-1)
bool(0) #False
bool(3.14)
bool(0.0) #False

#'','' 제외한 모든 문자열 True
bool("문자열") #무조건 True
bool("")       #무조건 False (공백이면)

# [], (), {} 등 빈 컨테이너(리스트, 튜블, 딕셔너리 등의 값이 비어 있는 경우)를 제외한 모든 자료형 True
# collection 자료형
bool([1, 2, 3]) # True
bool([])        # False
bool({1: a,})
# Out:
# True

# %% [markdown]
# > 단락 평가(short-circuit evalution) : 표현식에 대한 평가를 생략하는 방법

# %%
# 첫 번째 값이 거짓이므로 두 번째 값을 확인하지 않고 거짓으로 결정
False and True
10 < 1 and 3 == 3 and 4 % 2 == 0

# 첫 번째 값이 참이므로 두 번째 값을 확인하지 않고 참으로 결정
True or True
True or False
10 < 1 or 3 == 3 or 4 % 2 == 0

# 논리 연산식을 연결할 때 논리 판단 표현석의 순서에 따라서 프로그램의 선응에 영향을 준다.
# Out:
# True

# %% [markdown]
# > bool 의 사용 : if, while 등 조건식을 만들 때 사용

# %%
if True:
    print("참")

n = 12
if n % 2 == 0:
    print(f"{n}은 짝수 입니다.")
else:
    print(f"{n}은 홀수 입니다.")

li = []
print(li)
print(bool(li))

# 👍 
if li: #여기 False라 실행을 안함.
    li.append(2)
print(li) # [] 

if not li: #비어 있지 않다면
    li.append(2)
print(li) #[2]

if li: # 앞에 2가 들어 있으므로 작동 함.
    li.append(1)
print(li) #[1]
# Out:
# 참
# 12은 짝수 입니다.
# []
# False
# []
# [2]
# [2, 1]

# %%
# 프로그램에서 참과 거짓의 쓰임새 : while

if [1, 2, 3]:
    print("참")
else:
    print("거짓")

a = ['a', 'b', 'c', 'd', 'e', 'f']
print(a)

while a: #True 이면 돈다. // 즉 돈다
    a.pop()
    print(a)
# Out:
# 참
# ['a', 'b', 'c', 'd', 'e', 'f']
# ['a', 'b', 'c', 'd', 'e']
# ['a', 'b', 'c', 'd']
# ['a', 'b', 'c']
# ['a', 'b']
# ['a']
# []

# %% [markdown]
# > if 조건문 : 조건에 따라 코드의 실행을 분기하고자 할 때(실행의 흐름을 제어)

# %%
score = 55
CUT_LINE = 60
if score >=CUT_LINE:
    print("합격입니다")
else:
    print("불합격입니다")

# %%
# 사용자로부터 정수를 입력받아 양수, 음수를 판별하는 프로그램 작성(입력데이터 유효성 검증 처리 할 것)
# 👍내꺼 코드

no = input("숫자를 입력하세요: ")

if no.isalpha():
    print("정수가 아닙니다.")
    print("프로그램을 종료합니다.")
elif int(no) < 0:
    print("양수입니다.")
elif int(no) > 0:
    print("음수입니다.")
else:
    print("0입니다.")

# %%
# 👍강사님 코드

input_data = input("정수를 하나 입력하세요: ")
number = None

# 입력데이터 유효성 검증

# 숫자라면... // 이렇게도 한다보여주려고 not을 사용
if not input_data.isalpha():
    number = int(input_data)
    print("입력값: ", number)

#문자열이라면..
else:
    print("숫자가 아닙니다.")
    print("프로그램을 종료합니다.")
    quit()

# 양/음 수 판별
if number > 0:
    print("양수")
if number < 0:
    print("음수")
if number == 0:
    print("0")

# %%
# 👍학생코드

num = input("숫자를 입력하세요: ")

Pass = False

if num[0] == "-" :
    Pass = True
elif num.isnumeric() :
    Pass = True

# 👍학생코드
while Pass == False :
    num = input("실수(정수)가 아닙니다, 숫자를 입력하세요: ")
    if num[0] == "-" :
        Pass = True
    elif num.isnumeric() :
        Pass = True

if float(num) > 0:
    print('양수입니다')
elif num[0] == "-" :
    print('음수입니다')
else:
    print('0입니다')
# Out:
# 양수입니다
